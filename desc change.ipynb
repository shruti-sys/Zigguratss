# %%
import pandas as pd

# Sample DataFrame
df = pd.read_csv(r'C:\Users\aks\Desktop\zigguratss\image_descriptions.csv')
df.head()
# Out:
#    ImageID                                              Image  \
# 0        0  /content/drive/MyDrive/zigguratss-artwork-data...
# 1        1  /content/drive/MyDrive/zigguratss-artwork-data...
# 2        2  /content/drive/MyDrive/zigguratss-artwork-data...
# 3        3  /content/drive/MyDrive/zigguratss-artwork-data...
# 4        4  /content/drive/MyDrive/zigguratss-artwork-data...
#
#                                       Description  \
# 0               a drawing of a flower in a circle
# 1                 a drawing of a fish in a circle
# 2        a painting of a woman sitting on a chair
# 3  a painting of a woman with a basket and a bird
# 4           a painting of three women in a garden
#
#                          Keywords
# 0         flower, drawing, circle
# 1           fish, drawing, circle
# 2  woman sitting, painting, chair
# 3   woman, painting, bird, basket
# 4   three women, painting, garden

# %%
prefix_to_remove = '/content/drive/MyDrive/zigguratss-artwork-dataset/artwork-dataset/'

# Remove the prefix
df['Image'] = df['Image'].str.replace(prefix_to_remove, '', regex=False)

print("\nUpdated DataFrame:")
print(df.head())

# Save the updated DataFrame back to the same CSV file
df.to_csv(r'C:\Users\aks\Desktop\zigguratss\image_descriptions.csv', index=False)
# Out:
# Updated DataFrame:
#    ImageID          Image                                     Description  \
# 0        0    image_0.jpg               a drawing of a flower in a circle
# 1        1    image_1.jpg                 a drawing of a fish in a circle
# 2        2   image_10.jpg        a painting of a woman sitting on a chair
# 3        3  image_100.jpg  a painting of a woman with a basket and a bird
# 4        4  image_101.jpg           a painting of three women in a garden
#
#                          Keywords
# 0         flower, drawing, circle
# 1           fish, drawing, circle
# 2  woman sitting, painting, chair
# 3   woman, painting, bird, basket
# 4   three women, painting, garden

# %%
df.head(10)
# Out:
#    ImageID          Image                                        Description  \
# 0        0    image_0.jpg                  a drawing of a flower in a circle
# 1        1    image_1.jpg                    a drawing of a fish in a circle
# 2        2   image_10.jpg           a painting of a woman sitting on a chair
# 3        3  image_100.jpg     a painting of a woman with a basket and a bird
# 4        4  image_101.jpg              a painting of three women in a garden
# 5        5  image_102.jpg            a painting of a woman with a pink dress
# 6        6  image_103.jpg                 a painting of a lion in the clouds
# 7        7  image_104.jpg  a painting of a lion with green foliage on its...
# 8        8  image_105.jpg     a painting of a rock with a tree growing on it
# 9        9  image_106.jpg                     a lion with a fire on its face
#
#                               Keywords
# 0              flower, drawing, circle
# 1                fish, drawing, circle
# ...
